# %% [markdown]
# # Bank Marketing Campaign Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

#pull data
bank_data= pd.read_csv(r"C:\Users\wenxu\Desktop\RISE\Python\Packt Data Analysis Workshop\Bank Marketing Campaign Data\bank-additional-full.csv", sep=";")

# %%
#visualize the head of the dataset
bank_data.head().T
# Out:
#                           0            1            2            3  \
# age                      56           57           37           40
# job               housemaid     services     services       admin.
# marital             married      married      married      married
# education          basic.4y  high.school  high.school     basic.6y
# default                  no      unknown           no           no
# housing                  no           no          yes           no
# loan                     no           no           no           no
# contact           telephone    telephone    telephone    telephone
# month                   may          may          may          may
# day_of_week             mon          mon          mon          mon
# duration                261          149          226          151
# campaign                  1            1            1            1
# pdays                   999          999          999          999
# previous                  0            0            0            0
# poutcome        nonexistent  nonexistent  nonexistent  nonexistent
# emp.var.rate            1.1          1.1          1.1          1.1
# cons.price.idx       93.994       93.994       93.994       93.994
# cons.conf.idx         -36.4        -36.4        -36.4        -36.4
# euribor3m             4.857        4.857        4.857        4.857
# nr.employed          5191.0       5191.0       5191.0       5191.0
# y                        no           no           no           no
#
#                           4
# age                      56
# job                services
# marital             married
# education       high.school
# default                  no
# housing                  no
# loan                    yes
# contact           telephone
# month                   may
# day_of_week             mon
# duration                307
# campaign                  1
# pdays                   999
# previous                  0
# poutcome        nonexistent
# emp.var.rate            1.1
# cons.price.idx       93.994
# cons.conf.idx         -36.4
# euribor3m             4.857
# nr.employed          5191.0
# y                        no

# %%
bank_data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
# define numerical features
numerical_features = [col for col in bank_data.columns if np.issubdtype(bank_data[col].dtype, np.number)]
print(numerical_features)
# Out:
# ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# %%
# print statistics abnout the different numerical columns
bank_data[numerical_features].describe().T
# Out:
#                   count         mean         std       min       25%  \
# age             41188.0    40.024060   10.421250    17.000    32.000
# duration        41188.0   258.285010  259.279249     0.000   102.000
# campaign        41188.0     2.567593    2.770014     1.000     1.000
# pdays           41188.0   962.475454  186.910907     0.000   999.000
# previous        41188.0     0.172963    0.494901     0.000     0.000
# emp.var.rate    41188.0     0.081886    1.570960    -3.400    -1.800
# cons.price.idx  41188.0    93.575664    0.578840    92.201    93.075
# cons.conf.idx   41188.0   -40.502600    4.628198   -50.800   -42.700
# euribor3m       41188.0     3.621291    1.734447     0.634     1.344
# nr.employed     41188.0  5167.035911   72.251528  4963.600  5099.100
#
#                      50%       75%       max
# age               38.000    47.000    98.000
# duration         180.000   319.000  4918.000
# campaign           2.000     3.000    56.000
# pdays            999.000   999.000   999.000
# previous           0.000     0.000     7.000
# emp.var.rate       1.100     1.400     1.400
# cons.price.idx    93.749    93.994    94.767
# cons.conf.idx    -41.800   -36.400   -26.900
# euribor3m          4.857     4.961     5.045
# nr.employed     5191.000  5228.100  5228.100

# %%
# plot distributions of numerical features
plt.figure(figsize= (10,18))
for index, col in enumerate(numerical_features):
    plt.subplot(5,2,index+1)
    sns.distplot(bank_data[col], kde_kws={'bw':0.1})
# Out:
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### From the plots, only age and duration columns have a regular distribution of values, as the others seem scattered and only have a few values present.

# %%
# define categorical features
categorical_features= [col for col in bank_data.columns if pd.api.types.is_string_dtype(bank_data[col])]
print(categorical_features)
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y']

# %%
# plot distributions of categorical features
plt.figure(figsize= (25,35))
for index, col in enumerate(categorical_features):
    plt.subplot(6,2,index+1)
    ax= sns.countplot(y=col, data=bank_data)
    ax.set_xlabel("count", fontsize=20)
    ax.set_ylabel(col, fontsize=20)
    ax.tick_params(labelsize=20)

# %%
# compute number of entries in y column
print("Total number of entries:")
print(bank_data["y"].value_counts(ascending=False))
print()
print("Percentages:")
print(bank_data["y"].value_counts(normalize=True, ascending=False)*100)
# Out:
# Total number of entries:
# no     36548
# yes     4640
# Name: y, dtype: int64
#
# Percentages:
# no     88.734583
# yes    11.265417
# Name: y, dtype: float64

# %% [markdown]
# ### Only 11.3% of the contacted customers decide to accept the offer from the bank.

# %%
# create violin plots for succesful and non-succesful marketing campaigns

plt.figure(figsize=(10,18))
for index, col in enumerate(numerical_features):
    plt.subplot(5,2,index+1)
    sns.violinplot(x=col, y="y", data=bank_data, order=["yes","no"])

# %%
from scipy.stats import ttest_ind
# define function for computing mean of column for yes and no cases, as well as the test statistics and pvalue for equlity of means test

def test_means(data, col):
    yes_mask = data["y"] == "yes"
    values_yes = data[col][yes_mask]
    values_no = data[col][~yes_mask]
    mean_yes = values_yes.mean()
    mean_no = values_no.mean()
    
    ttest_res = ttest_ind(values_yes, values_no)
    
    return [col, mean_yes, mean_no, round(ttest_res[0], 4), round(ttest_res[1], 4)]

# %%
# define pandas dataframe, in which values should be filled
test_df= pd.DataFrame(columns= ["column", "mean yes", "mean no", "ttest stat", "ttest pval"])

# for each column in the numerical_features, compute means and test statistics and fill the values in the dataframe
for index, col in enumerate(numerical_features):
    test_df.loc[index] = test_means(bank_data, col)
    
test_df
# Out:
#            column     mean yes      mean no  ttest stat  ttest pval
# 0             age    40.913147    39.911185      6.1721         0.0
# 1        duration   553.191164   220.844807     89.9672         0.0
# 2        campaign     2.051724     2.633085    -13.4965         0.0
# 3           pdays   792.035560   984.113878    -69.7221         0.0
# 4        previous     0.492672     0.132374     48.0027         0.0
# 5    emp.var.rate    -1.233448     0.248875    -63.4337         0.0
# 6  cons.price.idx    93.354386    93.603757    -27.9032         0.0
# 7   cons.conf.idx   -39.789784   -40.593097     11.1539         0.0
# 8       euribor3m     2.123135     3.811491    -65.6466         0.0
# 9     nr.employed  5095.115991  5176.166600    -76.9845         0.0

# %% [markdown]
# ### There is a statistically significant difference in the mean values for each of the numerical columns(the results from the p-value in the ttest pval column). This means that for each of the numerical features, the average value for successful marketing campaigns is significantly different that the average value for unsuccesful marketing campaigns.

# %%
from scipy.stats import ks_2samp

# define function which performs Kolmogorov-Smirnov test, for provided column
def test_ks(data, col):
    yes_mask = data["y"] == "yes"
    values_yes = data[col][yes_mask]
    values_no = data[col][~yes_mask]
    
    kstest_res = ks_2samp(values_yes, values_no)
    return [col, round(kstest_res[0], 4), round(kstest_res[1], 4)]

# %%
# definte pandas dataframe, in which values should be filled
test_df = pd.DataFrame(columns=["column","ks stat", "ks pval"])

# for each column in the numerical_features, compute test statistics and fill the values in the dataframe
for index, col in enumerate(numerical_features):
    test_df.loc[index] = test_ks(bank_data, col)
    
test_df
# Out:
#            column  ks stat  ks pval
# 0             age   0.0861      0.0
# 1        duration   0.4641      0.0
# 2        campaign   0.0808      0.0
# 3           pdays   0.1934      0.0
# 4        previous   0.2102      0.0
# 5    emp.var.rate   0.4324      0.0
# 6  cons.price.idx   0.2281      0.0
# 7   cons.conf.idx   0.1998      0.0
# 8       euribor3m   0.4326      0.0
# 9     nr.employed   0.4324      0.0

# %% [markdown]
# ### We can observe that the distributions of the various numerical features present a significant difference between successful and unsuccessful marketing campaigns.

# %%
# create arrays containing campaign and financial columns
campaign_columns = ["age", "duration", "campaign", "previous"]
financial_columns = ["emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m"]

# %%
# create pairplot between campaign columns
plot_data = bank_data[campaign_columns + ["y"]]
plt.figure(figsize= (10,10))
sns.pairplot(plot_data, hue="y", palette="bright", diag_kws= {'bw':0.1})
# Out:
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\wenxu\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Most of the successful marketing campaigns were with newly contacted customers, while there isn't more than a single follow up for this campaign.

# %%
# create pairplot between financial features
plot_data = bank_data[financial_columns + ["y"]]
plt.figure(figsize= (10,10))
sns.pairplot(plot_data, hue="y", palette="bright")

# %% [markdown]
# ### Not surprisingly, the number of successful marketing calls drops as the 3-month interest rates(euribor3m column) increases. A possible explanation for this phenomenon is customer optimism when interest rates are lower.

# %%
# create mask for successful calls
successful_calls = bank_data.y == "yes"

# plot correlation matrix for successfull calls
plot_data = bank_data[campaign_columns + financial_columns][successful_calls]
successful_corr = plot_data.corr()
successful_corr.style.background_gradient(cmap= 'coolwarm').set_precision(3)
# Out:
# C:\Users\wenxu\AppData\Local\Temp/ipykernel_12900/28817730.py:7: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   successful_corr.style.background_gradient(cmap= 'coolwarm').set_precision(3)
# <style type="text/css">
# #T_203a7_row0_col0, #T_203a7_row1_col1, #T_203a7_row2_col2, #T_203a7_row3_col3, #T_203a7_row4_col4, #T_203a7_row5_col5, #T_203a7_row6_col6, #T_203a7_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_203a7_row0_col1, #T_203a7_row1_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_203a7_row0_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_203a7_row0_col3, #T_203a7_row2_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_203a7_row0_col4, #T_203a7_row7_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_203a7_row0_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_203a7_row0_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_203a7_row0_col7 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_203a7_row1_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_203a7_row1_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_203a7_row1_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_203a7_row1_col4 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_203a7_row1_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_203a7_row1_col7 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_203a7_row2_col0, #T_203a7_row6_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_203a7_row2_col1, #T_203a7_row3_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_203a7_row2_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_203a7_row2_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_203a7_row2_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_203a7_row2_col7 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_203a7_row3_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_203a7_row3_col1, #T_203a7_row3_col2, #T_203a7_row3_col4, #T_203a7_row3_col7, #T_203a7_row4_col0, #T_203a7_row5_col6, #T_203a7_row6_col5, #T_203a7_row7_col0, #T_203a7_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_203a7_row3_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_203a7_row4_col1, #T_203a7_row7_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_203a7_row4_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_203a7_row4_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_203a7_row4_col5 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_203a7_row4_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_203a7_row4_col7 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_203a7_row5_col0, #T_203a7_row6_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_203a7_row5_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_203a7_row5_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_203a7_row5_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_203a7_row5_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_203a7_row5_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_203a7_row6_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_203a7_row6_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_203a7_row6_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_203a7_row6_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_203a7_row7_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_203a7_row7_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_203a7_row7_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# </style>
# <table id="T_203a7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >duration</th>
#       <th class="col_heading level0 col2" >campaign</th>
#       <th class="col_heading level0 col3" >previous</th>
#       <th class="col_heading level0 col4" >emp.var.rate</th>
#       <th class="col_heading level0 col5" >cons.price.idx</th>
#       <th class="col_heading level0 col6" >cons.conf.idx</th>
#       <th class="col_heading level0 col7" >euribor3m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_203a7_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_203a7_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_203a7_row0_col1" class="data row0 col1" >-0.059</td>
#       <td id="T_203a7_row0_col2" class="data row0 col2" >-0.008</td>
#       <td id="T_203a7_row0_col3" class="data row0 col3" >0.075</td>
#       <td id="T_203a7_row0_col4" class="data row0 col4" >-0.082</td>
#       <td id="T_203a7_row0_col5" class="data row0 col5" >-0.025</td>
#       <td id="T_203a7_row0_col6" class="data row0 col6" >0.141</td>
#       <td id="T_203a7_row0_col7" class="data row0 col7" >-0.085</td>
#     </tr>
#     <tr>
#       <th id="T_203a7_level0_row1" class="row_heading level0 row1" >duration</th>
#       <td id="T_203a7_row1_col0" class="data row1 col0" >-0.059</td>
#       <td id="T_203a7_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_203a7_row1_col2" class="data row1 col2" >0.157</td>
#       <td id="T_203a7_row1_col3" class="data row1 col3" >-0.232</td>
#       <td id="T_203a7_row1_col4" class="data row1 col4" >0.503</td>
#       <td id="T_203a7_row1_col5" class="data row1 col5" >0.238</td>
#       <td id="T_203a7_row1_col6" class="data row1 col6" >-0.144</td>
#       <td id="T_203a7_row1_col7" class="data row1 col7" >0.500</td>
#     </tr>
#     <tr>
#       <th id="T_203a7_level0_row2" class="row_heading level0 row2" >campaign</th>
#       <td id="T_203a7_row2_col0" class="data row2 col0" >-0.008</td>
#       <td id="T_203a7_row2_col1" class="data row2 col1" >0.157</td>
#       <td id="T_203a7_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_203a7_row2_col3" class="data row2 col3" >-0.104</td>
#       <td id="T_203a7_row2_col4" class="data row2 col4" >0.222</td>
#       <td id="T_203a7_row2_col5" class="data row2 col5" >0.117</td>
#       <td id="T_203a7_row2_col6" class="data row2 col6" >-0.043</td>
#       <td id="T_203a7_row2_col7" class="data row2 col7" >0.212</td>
#     </tr>
#     <tr>
#       <th id="T_203a7_level0_row3" class="row_heading level0 row3" >previous</th>
#       <td id="T_203a7_row3_col0" class="data row3 col0" >0.075</td>
#       <td id="T_203a7_row3_col1" class="data row3 col1" >-0.232</td>
#       <td id="T_203a7_row3_col2" class="data row3 col2" >-0.104</td>
#       <td id="T_203a7_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_203a7_row3_col4" class="data row3 col4" >-0.285</td>
#       <td id="T_203a7_row3_col5" class="data row3 col5" >0.091</td>
#       <td id="T_203a7_row3_col6" class="data row3 col6" >0.128</td>
#       <td id="T_203a7_row3_col7" class="data row3 col7" >-0.392</td>
#     </tr>
#     <tr>
#       <th id="T_203a7_level0_row4" class="row_heading level0 row4" >emp.var.rate</th>
#       <td id="T_203a7_row4_col0" class="data row4 col0" >-0.082</td>
#       <td id="T_203a7_row4_col1" class="data row4 col1" >0.503</td>
#       <td id="T_203a7_row4_col2" class="data row4 col2" >0.222</td>
#       <td id="T_203a7_row4_col3" class="data row4 col3" >-0.285</td>
#       <td id="T_203a7_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_203a7_row4_col5" class="data row4 col5" >0.660</td>
#       <td id="T_203a7_row4_col6" class="data row4 col6" >-0.267</td>
#       <td id="T_203a7_row4_col7" class="data row4 col7" >0.926</td>
#     </tr>
#     <tr>
#       <th id="T_203a7_level0_row5" class="row_heading level0 row5" >cons.price.idx</th>
#       <td id="T_203a7_row5_col0" class="data row5 col0" >-0.025</td>
#       <td id="T_203a7_row5_col1" class="data row5 col1" >0.238</td>
#       <td id="T_203a7_row5_col2" class="data row5 col2" >0.117</td>
#       <td id="T_203a7_row5_col3" class="data row5 col3" >0.091</td>
#       <td id="T_203a7_row5_col4" class="data row5 col4" >0.660</td>
#       <td id="T_203a7_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_203a7_row5_col6" class="data row5 col6" >-0.328</td>
#       <td id="T_203a7_row5_col7" class="data row5 col7" >0.415</td>
#     </tr>
#     <tr>
#       <th id="T_203a7_level0_row6" class="row_heading level0 row6" >cons.conf.idx</th>
#       <td id=

# %%
# create mask for successful calls
unsuccessful_calls = bank_data.y == "no"
# plot correlation matrix for unsuccessfull calls
plot_data = bank_data[campaign_columns + financial_columns][unsuccessful_calls]
unsuccessful_corr = plot_data.corr()
unsuccessful_corr.style.background_gradient(cmap= 'coolwarm').set_precision(3)
# Out:
# C:\Users\wenxu\AppData\Local\Temp/ipykernel_12900/4046680201.py:6: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   unsuccessful_corr.style.background_gradient(cmap= 'coolwarm').set_precision(3)
# <style type="text/css">
# #T_15737_row0_col0, #T_15737_row1_col1, #T_15737_row2_col2, #T_15737_row3_col3, #T_15737_row4_col4, #T_15737_row5_col5, #T_15737_row6_col6, #T_15737_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_15737_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_15737_row0_col2, #T_15737_row7_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_15737_row0_col3, #T_15737_row1_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_15737_row0_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_15737_row0_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_15737_row0_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_15737_row0_col7, #T_15737_row6_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_15737_row1_col0, #T_15737_row1_col2, #T_15737_row2_col1, #T_15737_row3_col0, #T_15737_row3_col4, #T_15737_row3_col5, #T_15737_row3_col6, #T_15737_row3_col7, #T_15737_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_15737_row1_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_15737_row1_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_15737_row1_col6, #T_15737_row6_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_15737_row1_col7, #T_15737_row2_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_15737_row2_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_15737_row2_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_15737_row2_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_15737_row2_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_15737_row2_col7 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_15737_row3_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_15737_row3_col2, #T_15737_row4_col3, #T_15737_row5_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_15737_row4_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_15737_row4_col1, #T_15737_row6_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_15737_row4_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_15737_row4_col5 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_15737_row4_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_15737_row4_col7, #T_15737_row7_col4 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_15737_row5_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_15737_row5_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_15737_row5_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_15737_row5_col4 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_15737_row5_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_15737_row5_col7 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_15737_row6_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_15737_row6_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_15737_row6_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_15737_row6_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_15737_row7_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_15737_row7_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_15737_row7_col5 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_15737_row7_col6 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# </style>
# <table id="T_15737_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >duration</th>
#       <th class="col_heading level0 col2" >campaign</th>
#       <th class="col_heading level0 col3" >previous</th>
#       <th class="col_heading level0 col4" >emp.var.rate</th>
#       <th class="col_heading level0 col5" >cons.price.idx</th>
#       <th class="col_heading level0 col6" >cons.conf.idx</th>
#       <th class="col_heading level0 col7" >euribor3m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15737_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_15737_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_15737_row0_col1" class="data row0 col1" >0.001</td>
#       <td id="T_15737_row0_col2" class="data row0 col2" >0.008</td>
#       <td id="T_15737_row0_col3" class="data row0 col3" >-0.003</td>
#       <td id="T_15737_row0_col4" class="data row0 col4" >0.027</td>
#       <td id="T_15737_row0_col5" class="data row0 col5" >0.011</td>
#       <td id="T_15737_row0_col6" class="data row0 col6" >0.125</td>
#       <td id="T_15737_row0_col7" class="data row0 col7" >0.041</td>
#     </tr>
#     <tr>
#       <th id="T_15737_level0_row1" class="row_heading level0 row1" >duration</th>
#       <td id="T_15737_row1_col0" class="data row1 col0" >0.001</td>
#       <td id="T_15737_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_15737_row1_col2" class="data row1 col2" >-0.083</td>
#       <td id="T_15737_row1_col3" class="data row1 col3" >-0.004</td>
#       <td id="T_15737_row1_col4" class="data row1 col4" >0.003</td>
#       <td id="T_15737_row1_col5" class="data row1 col5" >0.018</td>
#       <td id="T_15737_row1_col6" class="data row1 col6" >0.004</td>
#       <td id="T_15737_row1_col7" class="data row1 col7" >0.006</td>
#     </tr>
#     <tr>
#       <th id="T_15737_level0_row2" class="row_heading level0 row2" >campaign</th>
#       <td id="T_15737_row2_col0" class="data row2 col0" >0.008</td>
#       <td id="T_15737_row2_col1" class="data row2 col1" >-0.083</td>
#       <td id="T_15737_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_15737_row2_col3" class="data row2 col3" >-0.068</td>
#       <td id="T_15737_row2_col4" class="data row2 col4" >0.133</td>
#       <td id="T_15737_row2_col5" class="data row2 col5" >0.123</td>
#       <td id="T_15737_row2_col6" class="data row2 col6" >-0.007</td>
#       <td id="T_15737_row2_col7" class="data row2 col7" >0.115</td>
#     </tr>
#     <tr>
#       <th id="T_15737_level0_row3" class="row_heading level0 row3" >previous</th>
#       <td id="T_15737_row3_col0" class="data row3 col0" >-0.003</td>
#       <td id="T_15737_row3_col1" class="data row3 col1" >-0.004</td>
#       <td id="T_15737_row3_col2" class="data row3 col2" >-0.068</td>
#       <td id="T_15737_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_15737_row3_col4" class="data row3 col4" >-0.425</td>
#       <td id="T_15737_row3_col5" class="data row3 col5" >-0.272</td>
#       <td id="T_15737_row3_col6" class="data row3 col6" >-0.139</td>
#       <td id="T_15737_row3_col7" class="data row3 col7" >-0.442</td>
#     </tr>
#     <tr>
#       <th id="T_15737_level0_row4" class="row_heading level0 row4" >emp.var.rate</th>
#       <td id="T_15737_row4_col0" class="data row4 col0" >0.027</td>
#       <td id="T_15737_row4_col1" class="data row4 col1" >0.003</td>
#       <td id="T_15737_row4_col2" class="data row4 col2" >0.133</td>
#       <td id="T_15737_row4_col3" class="data row4 col3" >-0.425</td>
#       <td id="T_15737_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_15737_row4_col5" class="data row4 col5" >0.797</td>
#       <td id="T_15737_row4_col6" class="data row4 col6" >0.319</td>
#       <td id="T_15737_row4_col7" class="data row4 col7" >0.976</td>
#     </tr>
#     <tr>
#       <th id="T_15737_level0_row5" class="row_heading level0 row5" >cons.price.idx</th>
#       <td id="T_15737_row5_col0" class="data row5 col0" >0.011</td>
#       <td id="T_15737_row5_col1" class="data row5 col1" >0.018</td>
#       <td id="T_15737_row5_col2" class="data row5 col2" >0.123</td>
#       <td id="T_15737_row5_col3" class="data row5 col3" >-0.272</td>
#       <td id="T_15737_row5_col4" class="data row5 col4" >0.797</td>
#       <td id="T_15737_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_15737_row5_col6" class="data row5 col6" >0.152</td>
#       <td id="T_15737_row5_col7" class="data row5 col7" >0.731</td>
#     </tr>
#     <tr>
#       <th id="T_15737_level0_row6" class="row_heading level0 row6" >cons.conf.idx</th>
#       <td id="T_15737_row6_col0" class="data row6 col0" >0.125</td>
#       <td id="T_15737_row6_col1" class="data row6

# %% [markdown]
# ### We observe that euribor3m(average interest rate at which european banks lend money to other banks with a maturity of 3 months) and emp.var.rate(rate at which people are hired or fired in an economy) correlation is very high. Positive correlation means that in an expanding economy, in which more people are hired then fired, interest rates tend to be higher.

# %% [markdown]
# ### Another column that is highly correlated with the previous two is the Consumer Price Index(CPI) column cons.price.idx. A high positive correlation of CPI with the other two columns is a clear indicator of an expanding economy, in which growing employment means more people with money, hence more spending and higher inflation. Central banks tend to increase interest rates in order to keep inflation under control, which is in line with our observation of increasing the euribor3m column.

# %%
# plot difference in successful - unsuccessful correlation matrices
diff_corr= successful_corr - unsuccessful_corr
diff_corr.style.background_gradient(cmap='coolwarm').set_precision(4)
# Out:
# C:\Users\wenxu\AppData\Local\Temp/ipykernel_12900/3030870194.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   diff_corr.style.background_gradient(cmap='coolwarm').set_precision(4)
# <style type="text/css">
# #T_55889_row0_col0 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_55889_row0_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_55889_row0_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_55889_row0_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_55889_row0_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_55889_row0_col5 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_55889_row0_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_55889_row0_col7, #T_55889_row3_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_55889_row1_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_55889_row1_col1 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_55889_row1_col2, #T_55889_row1_col4, #T_55889_row1_col7, #T_55889_row3_col0, #T_55889_row3_col5, #T_55889_row3_col6, #T_55889_row4_col1, #T_55889_row5_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_55889_row1_col3, #T_55889_row3_col1, #T_55889_row3_col2, #T_55889_row4_col6, #T_55889_row6_col2, #T_55889_row6_col4, #T_55889_row6_col5, #T_55889_row6_col7, #T_55889_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_55889_row1_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_55889_row1_col6 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_55889_row2_col0, #T_55889_row4_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_55889_row2_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_55889_row2_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_55889_row2_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_55889_row2_col4, #T_55889_row4_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_55889_row2_col5, #T_55889_row3_col7 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_55889_row2_col6 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_55889_row2_col7 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_55889_row3_col4 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_55889_row4_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_55889_row4_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_55889_row4_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_55889_row4_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_55889_row5_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_55889_row5_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_55889_row5_col2, #T_55889_row6_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_55889_row5_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_55889_row5_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_55889_row5_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_55889_row5_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_55889_row6_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_55889_row6_col3 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_55889_row6_col6 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_55889_row7_col1 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_55889_row7_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_55889_row7_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_55889_row7_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_55889_row7_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_55889_row7_col6 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_55889_row7_col7 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# </style>
# <table id="T_55889_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >duration</th>
#       <th class="col_heading level0 col2" >campaign</th>
#       <th class="col_heading level0 col3" >previous</th>
#       <th class="col_heading level0 col4" >emp.var.rate</th>
#       <th class="col_heading level0 col5" >cons.price.idx</th>
#       <th class="col_heading level0 col6" >cons.conf.idx</th>
#       <th class="col_heading level0 col7" >euribor3m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55889_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_55889_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_55889_row0_col1" class="data row0 col1" >-0.0601</td>
#       <td id="T_55889_row0_col2" class="data row0 col2" >-0.0163</td>
#       <td id="T_55889_row0_col3" class="data row0 col3" >0.0780</td>
#       <td id="T_55889_row0_col4" class="data row0 col4" >-0.1084</td>
#       <td id="T_55889_row0_col5" class="data row0 col5" >-0.0361</td>
#       <td id="T_55889_row0_col6" class="data row0 col6" >0.0165</td>
#       <td id="T_55889_row0_col7" class="data row0 col7" >-0.1268</td>
#     </tr>
#     <tr>
#       <th id="T_55889_level0_row1" class="row_heading level0 row1" >duration</th>
#       <td id="T_55889_row1_col0" class="data row1 col0" >-0.0601</td>
#       <td id="T_55889_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_55889_row1_col2" class="data row1 col2" >0.2402</td>
#       <td id="T_55889_row1_col3" class="data row1 col3" >-0.2273</td>
#       <td id="T_55889_row1_col4" class="data row1 col4" >0.4996</td>
#       <td id="T_55889_row1_col5" class="data row1 col5" >0.2199</td>
#       <td id="T_55889_row1_col6" class="data row1 col6" >-0.1480</td>
#       <td id="T_55889_row1_col7" class="data row1 col7" >0.4932</td>
#     </tr>
#     <tr>
#       <th id="T_55889_level0_row2" class="row_heading level0 row2" >campaign</th>
#       <td id="T_55889_row2_col0" class="data row2 col0" >-0.0163</td>
#       <td id="T_55889_row2_col1" class="data row2 col1" >0.2402</td>
#       <td id="T_55889_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_55889_row2_col3" class="data row2 col3" >-0.0363</td>
#       <td id="T_55889_row2_col4" class="data row2 col4" >0.0889</td>
#       <td id="T_55889_row2_col5" class="data row2 col5" >-0.0068</td>
#       <td id="T_55889_row2_col6" class="data row2 col6" >-0.0357</td>
#       <td id="T_55889_row2_col7" class="data row2 col7" >0.0965</td>
#     </tr>
#     <tr>
#       <th id="T_55889_level0_row3" class="row_heading level0 row3" >previous</th>
#       <td id="T_55889_row3_col0" class="data row3 col0" >0.0780</td>
#       <td id="T_55889_row3_col1" class="data row3 col1" >-0.2273</td>
#       <td id="T_55889_row3_col2" class="data row3 col2" >-0.0363</td>
#       <td id="T_55889_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_55889_row3_col4" class="data row3 col4" >0.1400</td>
#       <td id="T_55889_row3_col5" class="data row3 col5" >0.3631</td>
#       <td id="T_55889_row3_col6" class="data row3 col6" >0.2669</td>
#       <td id="T_55889_row3_col7" class="data row3 col7" >0.0504</td>
#     </tr>
#     <tr>
#       <th id="T_55889_level0_row4" class="row_heading level0 row4" >emp.var.rate</th>
#       <td id="T_55889_row4_col0" class="data row4 col0" >-0.1084</td>
#       <td id="T_55889_row4_col1" class="data row4 col1" >0.4996</td>
#       <td id="T_55889_row4_col2" class="data row4 col2" >0.0889</td>
#       <td id="T_55889_row4_col3" class="data row4 col3" >0.1400</td>
#       <td id="T_55889_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_55889_row4_col5" class="data row4 col5" >-0.1368</td>
#       <td id="T_55889_row4_col6" class="data row4 col6" >-0.5864</td>
#       <td id="T_55889_row4_col7" class="data row4 col7" >-0.0498</td>
#     </tr>
#     <tr>
#       <th id="T_55889_level0_row5" class="row_heading level0 row5" >cons.price.idx</th>
#       <td id="T_55889_row5_col0" class="data row5 col0" >-0.0361</td>
#       <td id="T_55889_row5_col1" class="data row5 col1" >0.2199</td>
#       <td id="T_55889_row5_col2" class="data row5 col2" >-0.0068</td>
#       <td id="T_55889_row5_col3" class="data row5 col3" >0.3631</td>
#       <td id="T_55889_row5_col4" class="data row5 col4" >-0.1368</td>
#       <td id="T_55889_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_55889_row5_col6" class="data row5 col6" >-0.4806</td>
#       <td id="T_55889_row5_col7" class

# %% [markdown]
# ### It is always important to remember that correlation does not imply causation. duration and emp.var.rate has a significant difference in the correlations, but the duration of the call should not be influenced by a macroeconomic factor like the employment variation rate or vice versa.

# %% [markdown]
# ### Interesting fact: the consumer confidence index(cons.conf.idx) is negatively correlated with the 3 mentioned columns(emp.var.rate, cons.price.idx and euribor3m) for successful customer calls and positively correlated for unsuccessful ones. This means that when the overall economic sentiment is pessimistic, people are willing to accept the new banking products and vice versa.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### Applying linear regression in order to predict the consumer confidence index (cons.conf.idx column) based on the employment variation rate(emp.var.rate), CPI(cons.price.idx) and the 3-month interest rate(euribor3m).

# %%
import statsmodels.api as sm

# create feature matrix and target variable
X = bank_data[["emp.var.rate", "cons.price.idx", "euribor3m"]]
# add constant value for the intercept term
X = sm.add_constant(X)
y = bank_data["cons.conf.idx"]

#define and fit model
lineare_regression_model = sm.OLS(y, X)
result = lineare_regression_model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          cons.conf.idx   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     2960.
# Date:                Mon, 25 Sep 2023   Prob (F-statistic):               0.00
# Time:                        21:22:23   Log-Likelihood:            -1.1753e+05
# No. Observations:               41188   AIC:                         2.351e+05
# Df Residuals:                   41184   BIC:                         2.351e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            -82.4025      5.999    -13.736      0.000     -94.161     -70.644
# emp.var.rate      -4.1814      0.072    -57.960      0.000      -4.323      -4.040
# cons.price.idx     0.2828      0.063      4.478      0.000       0.159       0.407
# euribor3m          4.3582      0.057     76.618      0.000       4.247       4.470
# ==============================================================================
# Omnibus:                     3246.559   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4034.493
# Skew:                           0.761   Prob(JB):                         0.00
# Kurtosis:                       2.811   Cond. No.                     2.72e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.72e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Adj. R-squared metric takes into account the accuracy of the model (where value close to 0 mean predicting the average value of the target variable, thus almost no predictive power, while values close to 1 indicate a very accurate prediction model) Adj R-squared tends to increase as there are more features in the complexity of the model.

# %% [markdown]
# ### coef column shows that cons.conf.idx is positively correlated with the cons.price.idx and euribor3m columns, and negatively correlated with emp.var.rate.

# %% [markdown]
# ### P>|t| returns the p-value of the hypothesis test, in which the null hypothesis is that the relative coefficient is equal to zero. As the p-values are 0, each of the coefficients is statistically significant in our equation (when p-values are large, the feature associated with that value is not relevent for our linear regression model and can be removed from the equation without deteriorating the accuracy of the model).

# %% [markdown]
# # Logistic Regression

# %%
# create feature matrix and target variable
X = bank_data[["age", "duration", "campaign", "previous"]]
# add constant value for the intercept term
X = sm.add_constant(X)
# target has to be numeric
y = np.where(bank_data["y"] == "yes", 1,0)

# define and fit model
logistic_regression_model = sm.Logit(y, X)
result = logistic_regression_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.269969
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                41188
# Model:                          Logit   Df Residuals:                    41183
# Method:                           MLE   Df Model:                            4
# Date:                Mon, 25 Sep 2023   Pseudo R-squ.:                  0.2331
# Time:                        21:22:24   Log-Likelihood:                -11119.
# converged:                       True   LL-Null:                       -14499.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7793      0.076    -49.435      0.000      -3.929      -3.629
# age            0.0091      0.002      5.665      0.000       0.006       0.012
# duration       0.0039   6.16e-05     62.973      0.000       0.004       0.004
# campaign      -0.1163      0.011    -10.706      0.000      -0.138      -0.095
# previous       1.0579      0.027     39.232      0.000       1.005       1.111
# ==============================================================================

# %%
# transform all features into numerical ones, by using the get_dummies() function
X = bank_data.drop("y", axis=1)
X = pd.get_dummies(X)
X= sm.add_constant(X)
print(X.columns)
# Out:
# Index(['const', 'age', 'duration', 'campaign', 'pdays', 'previous',
#        'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m',
#        'nr.employed', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
#        'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
#        'job_services', 'job_student', 'job_technician', 'job_unemployed',
#        'job_unknown', 'marital_divorced', 'marital_married', 'marital_single',
#        'marital_unknown', 'education_basic.4y', 'education_basic.6y',
#        'education_basic.9y', 'education_high.school', 'education_illiterate',
#        'education_professional.course', 'education_university.degree',
#        'education_unknown', 'default_no', 'default_unknown', 'default_yes',
#        'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
#        'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
#        'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu',
#        'day_of_week_tue', 'day_of_week_wed', 'poutcome_failure',
#        'poutcome_nonexistent', 'poutcome_success'],
#       dtype='object')

# %%
# extract and transform target variable
y = np.where(bank_data["y"] == "yes", 1, 0)

# %%
# define and fit model
full_logistic_regression_model = sm.Logit(y, X)
result = full_logistic_regression_model.fit(maxiter=500)
print(result.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.207316
#          Iterations: 500
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                41188
# Model:                          Logit   Df Residuals:                    41135
# Method:                           MLE   Df Model:                           52
# Date:                Mon, 25 Sep 2023   Pseudo R-squ.:                  0.4111
# Time:                        21:22:40   Log-Likelihood:                -8538.9
# converged:                      False   LL-Null:                       -14499.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                           -67.1298        nan        nan        nan         nan         nan
# age                               0.0002      0.002      0.081      0.936      -0.005       0.005
# duration                          0.0047   7.46e-05     63.108      0.000       0.005       0.005
# campaign                         -0.0401      0.012     -3.473      0.001      -0.063      -0.017
# pdays                            -0.0009      0.000     -4.326      0.000      -0.001      -0.001
# previous                         -0.0628      0.059     -1.062      0.288      -0.179       0.053
# emp.var.rate                     -1.7576      0.142    -12.380      0.000      -2.036      -1.479
# cons.price.idx                    2.1905      0.252      8.679      0.000       1.696       2.685
# cons.conf.idx                     0.0207      0.008      2.664      0.008       0.005       0.036
# euribor3m                         0.3316      0.130      2.551      0.011       0.077       0.586
# nr.employed                       0.0054      0.003      1.738      0.082      -0.001       0.012
# job_admin.                       -5.5637   6.02e+05  -9.24e-06      1.000   -1.18e+06    1.18e+06
# job_blue-collar                  -5.7985   5.35e+05  -1.08e-05      1.000   -1.05e+06    1.05e+06
# job_entrepreneur                 -5.7418   4.76e+05  -1.21e-05      1.000   -9.33e+05    9.33e+05
# job_housemaid                    -5.5880   5.28e+05  -1.06e-05      1.000   -1.04e+06    1.04e+06
# job_management                   -5.6199   5.15e+05  -1.09e-05      1.000   -1.01e+06    1.01e+06
# job_retired                      -5.2780   5.01e+05  -1.05e-05      1.000   -9.82e+05    9.82e+05
# job_self-employed                -5.7215   5.46e+05  -1.05e-05      1.000   -1.07e+06    1.07e+06
# job_services                     -5.7036   5.14e+05  -1.11e-05      1.000   -1.01e+06    1.01e+06
# job_student                      -5.3604   4.84e+05  -1.11e-05      1.000   -9.48e+05    9.48e+05
# job_technician                   -5.5777   5.09e+05   -1.1e-05      1.000   -9.98e+05    9.98e+05
# job_unemployed                   -5.5426   4.78e+05  -1.16e-05      1.000   -9.36e+05    9.36e+05
# job_unknown                      -5.6342   5.21e+05  -1.08e-05      1.000   -1.02e+06    1.02e+06
# marital_divorced                -16.8032        nan        nan        nan         nan         nan
# marital_married                 -16.8059        nan        nan        nan         nan         nan
# marital_single                  -16.7472        nan        nan        nan         nan         nan
# marital_unknown                 -16.7737        nan        nan        nan         nan         nan
# education_basic.4y               -8.6034   1.47e+06  -5.86e-06      1.000   -2.88e+06    2.88e+06
# education_basic.6y               -8.4808   1.47e+06  -5.76e-06      1.000   -2.89e+06    2.89e+06
# education_basic.9y               -8.6044   1.49e+06  -5.76e-06      1.000   -2.93e+06    2.93e+06
# education_high.school            -8.5548   1.54e+06  -5.57e-06      1.000   -3.01e+06    3.01e+06
# education_illiterate             -7.5368   1.47e+06  -5.13e-06      1.000   -2.88e+06    2.88e+06
# education_professional.course    -8.4884   1.45e+06  -5.86e-06      1.000   -2.84e+06    2.84e+06
# education_university.degree      -8.4076   1.49e+06  -5.65e-06      1.000   -2.92e+06    2.92e+06
# education_unknown                -8.4537   1.52e+06  -5.56e-06      1.000   -2.98e+06    2.98e+06
# default_no                      -17.2831        nan        nan        nan         nan         nan
# default_unknown                 -17.5834        nan        nan        nan         nan         nan
# default_yes                     -32.2636        nan        nan        nan         nan         nan
# housing_no                      -22.3634        nan        nan        nan         nan         nan
# housing_unknown                 -22.3984        nan        nan        nan         nan         nan
# housing_yes                     -22.3681        nan        nan        nan         nan         nan
# loan_no                         -22.3400        nan        nan        nan         nan         nan
# loan_unknown                    -22.3984        nan        nan        nan         nan         nan
# loan_yes                        -22.3916        nan        nan        nan         nan         nan
# contact_cellular                -33.2419        nan        nan        nan         nan         nan
# contact_telephone               -33.8879        nan        nan        nan         nan         nan
# month_apr                        -6.9645        nan        nan        nan         nan         nan
# month_aug                        -6.0992        nan        nan        nan         nan         nan
# month_dec                        -6.6453        nan        nan        nan         nan         nan
# month_jul                        -6.8299        nan        nan        nan         nan         nan
# month_jun                        -7.4888        nan        nan        nan         nan         nan
# month_mar                        -4.9504        nan        nan        nan         nan         nan
# month_may                        -7.4084        nan        nan        nan         nan         nan
# month_nov                        -7.3825        nan        nan        nan         nan         nan
# month_oct                        -6.7705        nan        nan        nan         nan         nan
# month_sep                        -6.5905        nan        nan        nan         nan         nan
# day_of_week_fri                 -13.4683        nan        nan        nan         nan         nan
# day_of_week_mon                 -13.5851        nan        nan        nan         nan         nan
# day_of_week_thu                 -13.4123        nan        nan        nan         nan         nan
# day_of_week_tue                 -13.3711        nan        nan        nan         nan         nan
# day_of_week_wed                 -13.2930        nan        nan        nan         nan         nan
# poutcome_failure                -22.8385        nan        nan        nan         nan         nan
# poutcome_nonexistent            -22.4127        nan        nan        nan         nan         nan
# poutcome_success                -21.8788        nan        nan        nan         nan         nan
# =================================================================================================
# C:\Users\wenxu\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ### Important to note that P>|z| column has values that is equal to 1, which means that we cannot reject the null hypothesis stating that the coefficient for the respective column should be equal to zero. In otherwords, we have lots of redundant columns in our model.

# %% [markdown]
# ### Furthermore, for some of the coefficients, we cannot even compute the p-values(NaN values), indicating that the optimization model running is not able to converge, which is another reason to reduce the number of features.

# %% [markdown]
# # Creating a leaner logistic regression model

# %%
# create feature matrix using a selection of the variables with a p-value smaller than 0.05 from the logistic model above
X = bank_data[["duration", "campaign", "pdays", "emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m"]]
# add constant value for the intercept term
X = sm.add_constant(X)
X.head()
# Out:
#    const  duration  campaign  pdays  emp.var.rate  cons.price.idx  \
# 0    1.0       261         1    999           1.1          93.994
# 1    1.0       149         1    999           1.1          93.994
# 2    1.0       226         1    999           1.1          93.994
# 3    1.0       151         1    999           1.1          93.994
# 4    1.0       307         1    999           1.1          93.994
#
#    cons.conf.idx  euribor3m
# 0          -36.4      4.857
# 1          -36.4      4.857
# 2          -36.4      4.857
# 3          -36.4      4.857
# 4          -36.4      4.857

# %%
# extract and transform target variable
y = np.where(bank_data["y"] == "yes", 1, 0)

# %%
# define and fit model
logistic_regression_model = sm.Logit(y, X)
result = logistic_regression_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.220751
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                41188
# Model:                          Logit   Df Residuals:                    41180
# Method:                           MLE   Df Model:                            7
# Date:                Mon, 25 Sep 2023   Pseudo R-squ.:                  0.3729
# Time:                        21:22:40   Log-Likelihood:                -9092.3
# converged:                       True   LL-Null:                       -14499.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            -90.4650      5.683    -15.919      0.000    -101.603     -79.327
# duration           0.0045   7.16e-05     63.562      0.000       0.004       0.005
# campaign          -0.0432      0.011     -3.800      0.000      -0.065      -0.021
# pdays             -0.0016   6.82e-05    -22.967      0.000      -0.002      -0.001
# emp.var.rate      -0.7114      0.066    -10.739      0.000      -0.841      -0.582
# cons.price.idx     0.9698      0.059     16.420      0.000       0.854       1.086
# cons.conf.idx      0.0513      0.004     13.143      0.000       0.044       0.059
# euribor3m         -0.1996      0.051     -3.950      0.000      -0.299      -0.101
# ==================================================================================

# %% [markdown]
# ### Pr(y=yes) = exp(-90.4650 + 0.0045*duration - 0.0432*campaign - 0.0016*pdays - 0.7114*emp.var.rate + 0.9698*cons.price.idx + 0.0513*cons.conf.idx - 0.1996*euribor3m) / (1 + exp(-90.4650 + 0.0045*duration - 0.0432*campaign - 0.0016*pdays - 0.7114*emp.var.rate + 0.9698*cons.price.idx + 0.0513*cons.conf.idx - 0.1996*euribor3m))

# %% [markdown]
# ### Pr(y=no) = 1 / (1 + exp(-90.4650 + 0.0045*duration - 0.0432*campaign - 0.0016*pdays - 0.7114*emp.var.rate + 0.9698*cons.price.idx + 0.0513*cons.conf.idx - 0.1996*euribor3m))
